# %%
import pandas as pd

# %%
nj_transit_tweets = pd.read_csv('../scrapers/csvs/@NJTRANSIT_RVL_march_april_may.csv')
string = "RVL_nj_transit_tweets.csv"
train_line = "RVL"

# %%
nj_transit_tweets.head(5)
# Out:
#                    id           created_at  \
# 0  872868526654185472  2017-06-08 13:30:48
# 1  872866255853809666  2017-06-08 13:21:47
# 2  872812345176838145  2017-06-08 09:47:33
# 3  872796703803441154  2017-06-08 08:45:24
# 4  872517902091550720  2017-06-07 14:17:33
#
#                                                 text  \
# 0  RVL: Delays Estimated up to 20 Min. due to Tra...
# 1  Raritan Valley Line: Delays Estimated up to 20...
# 2  UPDATE: Train service in/out of Penn Station N...
# 3  Train service in/out of PSNY is subject to up ...
# 4  RVL train #5175 the 2:09pm from Raritan is up ...
#
#                                            tweetlink
# 0  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 1  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 2  https://twitter.com/NJTRANSIT_RVL/status/87281...
# 3  https://twitter.com/NJTRANSIT_RVL/status/87279...
# 4  https://twitter.com/NJTRANSIT_RVL/status/87251...

# %%
len(nj_transit_tweets.index)
# Out:
# 3236

# %%
#Take out Twitter replies
nj_transit_tweets_no_replies = nj_transit_tweets[~nj_transit_tweets['text'].str.contains("^[@]\S*")]
nj_transit_tweets_all_replies = nj_transit_tweets[nj_transit_tweets['text'].str.contains("^[@]\S*")]

# %%
nj_transit_tweets_no_replies.head(5)
# Out:
#                    id           created_at  \
# 0  872868526654185472  2017-06-08 13:30:48
# 1  872866255853809666  2017-06-08 13:21:47
# 2  872812345176838145  2017-06-08 09:47:33
# 3  872796703803441154  2017-06-08 08:45:24
# 4  872517902091550720  2017-06-07 14:17:33
#
#                                                 text  \
# 0  RVL: Delays Estimated up to 20 Min. due to Tra...
# 1  Raritan Valley Line: Delays Estimated up to 20...
# 2  UPDATE: Train service in/out of Penn Station N...
# 3  Train service in/out of PSNY is subject to up ...
# 4  RVL train #5175 the 2:09pm from Raritan is up ...
#
#                                            tweetlink
# 0  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 1  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 2  https://twitter.com/NJTRANSIT_RVL/status/87281...
# 3  https://twitter.com/NJTRANSIT_RVL/status/87279...
# 4  https://twitter.com/NJTRANSIT_RVL/status/87251...

# %%
#Take out Light Rail
nj_transit_tweets_no_light_rail = nj_transit_tweets_no_replies[~nj_transit_tweets_no_replies['text'].str.contains("light rail|Light Rail|#HBLR|#NLR|ACRL")]
nj_transit_tweets_all_light_rail = nj_transit_tweets_no_replies[nj_transit_tweets_no_replies['text'].str.contains("light rail|Light Rail|#HBLR|#NLR|ACRL")]

# %%
nj_transit_tweets_no_light_rail.head(5)
# Out:
#                    id           created_at  \
# 0  872868526654185472  2017-06-08 13:30:48
# 1  872866255853809666  2017-06-08 13:21:47
# 2  872812345176838145  2017-06-08 09:47:33
# 3  872796703803441154  2017-06-08 08:45:24
# 4  872517902091550720  2017-06-07 14:17:33
#
#                                                 text  \
# 0  RVL: Delays Estimated up to 20 Min. due to Tra...
# 1  Raritan Valley Line: Delays Estimated up to 20...
# 2  UPDATE: Train service in/out of Penn Station N...
# 3  Train service in/out of PSNY is subject to up ...
# 4  RVL train #5175 the 2:09pm from Raritan is up ...
#
#                                            tweetlink
# 0  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 1  https://twitter.com/NJTRANSIT_RVL/status/87286...
# 2  https://twitter.com/NJTRANSIT_RVL/status/87281...
# 3  https://twitter.com/NJTRANSIT_RVL/status/87279...
# 4  https://twitter.com/NJTRANSIT_RVL/status/87251...

# %%
len(nj_transit_tweets_no_light_rail.index)
# Out:
# 3207

# %%
nj_transit_tweets_no_rt = nj_transit_tweets_no_light_rail[~nj_transit_tweets_no_light_rail['text'].str.contains("^RT\s@")]
nj_transit_tweets_all_rt = nj_transit_tweets_no_light_rail[nj_transit_tweets_no_light_rail['text'].str.contains("^RT\s@")]

# %%
nj_transit_tweets_all_rt.head(5)
# Out:
# Empty DataFrame
# Columns: [id, created_at, text, tweetlink]
# Index: []

# %%
len(nj_transit_tweets_no_rt.index)
# Out:
# 3207

# %%
#Take out Bus
nj_transit_tweets_no_bus = nj_transit_tweets_no_rt[~nj_transit_tweets_no_rt['text'].str.contains("Bus service|bus service|bus Service|Bus lanes|Bus route|road conditions")]
nj_transit_tweets_all_bus = nj_transit_tweets_no_rt[nj_transit_tweets_no_rt['text'].str.contains("Bus service|bus service|bus Service|Bus lanes|Bus route|road conditions")]

# %%
#Take out Ferry
nj_transit_tweets_no_ferry = nj_transit_tweets_no_bus[~nj_transit_tweets_no_bus['text'].str.contains("Ferry|ferry|Waterway")]
nj_transit_tweets_all_ferry = nj_transit_tweets_no_bus[nj_transit_tweets_no_bus['text'].str.contains("Ferry|ferry|Waterway")]

# %%
#Take out Promotions
nj_transit_tweets_no_promo = nj_transit_tweets_no_ferry[~nj_transit_tweets_no_ferry['text'].str.contains("Save|save|sale|Save|Code|code|#WeRListening|#TTFatWork|St. Patrick's Day")]
nj_transit_tweets_all_promo = nj_transit_tweets_no_ferry[nj_transit_tweets_no_ferry['text'].str.contains("Save|save|sale|Save|Code|code|#WeRListening|#TTFatWork|St. Patrick's Day")]

# %%
len(nj_transit_tweets_no_promo.index)
# Out:
# 3178

# %%
import datetime
datetime.datetime.strptime
# Out:
# <function strptime>

# %%
#convert to datetime so I can filter out dates 
#Example 2017-04-25 17:33:25 %m/%m/

nj_transit_tweets_no_promo['created_at_date'] =  pd.to_datetime(nj_transit_tweets_no_promo['created_at'], format='%Y-%m-%d %H:%M:%S')

# %%
nj_transit_tweets_no_promo.head(10)
# Out:
#                    id           created_at  \
# 0  872868526654185472  2017-06-08 13:30:48
# 1  872866255853809666  2017-06-08 13:21:47
# 2  872812345176838145  2017-06-08 09:47:33
# 3  872796703803441154  2017-06-08 08:45:24
# 4  872517902091550720  2017-06-07 14:17:33
# 5  872501332015534080  2017-06-07 13:11:42
# 6  872484018805145601  2017-06-07 12:02:54
# 7  872482022748557312  2017-06-07 11:54:58
# 8  872476458358374401  2017-06-07 11:32:52
# 9  872463495811538945  2017-06-07 10:41:21
#
#                                                 text  \
# 0  RVL: Delays Estimated up to 20 Min. due to Tra...
# 1  Raritan Valley Line: Delays Estimated up to 20...
# 2  UPDATE: Train service in/out of Penn Station N...
# 3  Train service in/out of PSNY is subject to up ...
# 4  RVL train #5175 the 2:09pm from Raritan is up ...
# 5  RVL train #5123 the 12:51pm from Bound Brook i...
# 6  RVL train #5121, the 11:49am from Bound Brook ...
# 7  Hot 97 Summer Jam: NJ TRANSIT Offers Rail Shut...
# 8  RVL train #5719, the 11:16am from White house ...
# 9  Update: Train service in/out of Penn Station N...
#
#                                            tweetlink     created_at_date
# 0  https://twitter.com/NJTRANSIT_RVL/status/87286... 2017-06-08 13:30:48
# 1  https://twitter.com/NJTRANSIT_RVL/status/87286... 2017-06-08 13:21:47
# 2  https://twitter.com/NJTRANSIT_RVL/status/87281... 2017-06-08 09:47:33
# 3  https://twitter.com/NJTRANSIT_RVL/status/87279... 2017-06-08 08:45:24
# 4  https://twitter.com/NJTRANSIT_RVL/status/87251... 2017-06-07 14:17:33
# 5  https://twitter.com/NJTRANSIT_RVL/status/87250... 2017-06-07 13:11:42
# 6  https://twitter.com/NJTRANSIT_RVL/status/87248... 2017-06-07 12:02:54
# 7  https://twitter.com/NJTRANSIT_RVL/status/87248... 2017-06-07 11:54:58
# 8  https://twitter.com/NJTRANSIT_RVL/status/87247... 2017-06-07 11:32:52
# 9  https://twitter.com/NJTRANSIT_RVL/status/87246... 2017-06-07 10:41:21

# %%
nj_transit_tweets_filtered = nj_transit_tweets_no_promo[(nj_transit_tweets_no_promo['created_at_date']>datetime.date(2017,3,1)) & (nj_transit_tweets_no_promo['created_at_date']<datetime.date(2017,5,31))]

# %%
nj_transit_tweets_filtered.tail(10)
# Out:
#                      id           created_at  \
# 526  838828445169774592  2017-03-06 15:07:40
# 527  838814466313715712  2017-03-06 14:12:07
# 528  838796760290111488  2017-03-06 13:01:46
# 529  838781874357010434  2017-03-06 12:02:37
# 530  838767772691750917  2017-03-06 11:06:35
# 531  837841778195718145  2017-03-03 21:47:00
# 532  837409811436294144  2017-03-02 17:10:32
# 533  837328766225563649  2017-03-02 11:48:29
# 534  837318718086660096  2017-03-02 11:08:33
# 535  837296985346568192  2017-03-02 09:42:12
#
#                                                   text  \
# 526  RVL train #5175 the 1:51pm from Bound Brook is...
# 527  RVL train #5123, the 12:59pm from Somerville, ...
# 528  RVL train #5121, the 11:49am from Bound Brook ...
# 529  RVL train #5719 the 10:51am from Bound Brook i...
# 530  RVL train #5415 the 9:49am from Bound Brook is...
# 531  RVL train #5451 the 8:35pm from Westfield is u...
# 532  The Newark Air Train monorail has resumed norm...
# 533  Newark Air Train monorail is suspended due hig...
# 534  Update: NEC, NJCL and RVL trains are now opera...
# 535  Update: NEC, NJCL &amp; RVL rail svc is subj. ...
#
#                                              tweetlink     created_at_date
# 526  https://twitter.com/NJTRANSIT_RVL/status/83882... 2017-03-06 15:07:40
# 527  https://twitter.com/NJTRANSIT_RVL/status/83881... 2017-03-06 14:12:07
# 528  https://twitter.com/NJTRANSIT_RVL/status/83879... 2017-03-06 13:01:46
# 529  https://twitter.com/NJTRANSIT_RVL/status/83878... 2017-03-06 12:02:37
# 530  https://twitter.com/NJTRANSIT_RVL/status/83876... 2017-03-06 11:06:35
# 531  https://twitter.com/NJTRANSIT_RVL/status/83784... 2017-03-03 21:47:00
# 532  https://twitter.com/NJTRANSIT_RVL/status/83740... 2017-03-02 17:10:32
# 533  https://twitter.com/NJTRANSIT_RVL/status/83732... 2017-03-02 11:48:29
# 534  https://twitter.com/NJTRANSIT_RVL/status/83731... 2017-03-02 11:08:33
# 535  https://twitter.com/NJTRANSIT_RVL/status/83729... 2017-03-02 09:42:12

# %%
#Keep all of the delays/suspensions/cancellations
nj_transit_tweets_no_delays = nj_transit_tweets_filtered[~nj_transit_tweets_filtered['text'].str.contains("delays|delay|delayed|cancelled|CANCELLED|Cancelled|suspended|suspend|late|stopped in the station")]
nj_transit_tweets_all_delays = nj_transit_tweets_filtered[nj_transit_tweets_filtered['text'].str.contains("delays|delay|delayed|cancelled|CANCELLED|Cancelled|suspended|suspend|late|stopped in the station")]

# %%
len(nj_transit_tweets_no_delays.index)
# Out:
# 140

# %%
len(nj_transit_tweets_all_delays.index)
# Out:
# 335

# %%
#Take out updates
nj_transit_tweets_no_updates = nj_transit_tweets_all_delays[~nj_transit_tweets_all_delays['text'].str.contains("update|Update|UPDATE|Correction|CORRECTION")]
nj_transit_tweets_all_updates = nj_transit_tweets_all_delays[nj_transit_tweets_all_delays['text'].str.contains("update|Update|UPDATE|Correction|CORRECTION")]

# %%
len(nj_transit_tweets_no_updates.index)
# Out:
# 271

# %%
#Take out Princeton Dinky and Air Train and PATH and Metro North
nj_transit_tweets_no_dinky = nj_transit_tweets_no_updates[~nj_transit_tweets_no_updates['text'].str.contains("Dinky|Air Train|Airtrain|AirTrain|PATH|Metro North")]
nj_transit_tweets_all_dinky = nj_transit_tweets_no_updates[nj_transit_tweets_no_updates['text'].str.contains("Dinky|Air Train|Airtrain|AirTrain|PATH|Metro North")]

# %%
len(nj_transit_tweets_no_dinky.index)
# Out:
# 269

# %%
#Take out operating close to normal schedule
nj_transit_tweets_no_normal = nj_transit_tweets_no_dinky[~nj_transit_tweets_no_dinky['text'].str.contains("operating on or close to schedule|close to schedule")]
nj_transit_tweets_all_normal = nj_transit_tweets_no_dinky[nj_transit_tweets_no_dinky['text'].str.contains("operating on or close to schedule|close to schedule")]

# %%
len(nj_transit_tweets_no_normal.index)
# Out:
# 249

# %%
#Get partial string for reason for delay and try to make it into column
regex = "due[^.]*"

nj_transit_tweets_no_normal['reason'] = nj_transit_tweets_no_normal['text'].str.extract('('+regex+')', expand=False)
# Out:
# /Users/castudi1/miniconda2/envs/lovepandas/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nj_transit_tweets_no_normal.head(5)
# Out:
#                     id           created_at  \
# 42  869707161642782721  2017-05-30 20:08:40
# 44  869610601156423680  2017-05-30 13:44:58
# 45  869555488987516930  2017-05-30 10:05:58
# 47  869535347184721921  2017-05-30 08:45:56
# 48  869524519790280704  2017-05-30 08:02:55
#
#                                                  text  \
# 42  Train service in/out of Penn Station New York ...
# 44  RVL train #5176, the 1:28pm from Cranford is  ...
# 45  Train service in/out of Penn Station New York ...
# 47  (1 of 2) Trains in/out of PSNY is subject to u...
# 48  Train service in/out of PSNY is subject to up ...
#
#                                             tweetlink     created_at_date  \
# 42  https://twitter.com/NJTRANSIT_RVL/status/86970... 2017-05-30 20:08:40
# 44  https://twitter.com/NJTRANSIT_RVL/status/86961... 2017-05-30 13:44:58
# 45  https://twitter.com/NJTRANSIT_RVL/status/86955... 2017-05-30 10:05:58
# 47  https://twitter.com/NJTRANSIT_RVL/status/86953... 2017-05-30 08:45:56
# 48  https://twitter.com/NJTRANSIT_RVL/status/86952... 2017-05-30 08:02:55
#
#                                              reason
# 42                                              NaN
# 44  due to track maintenance and a late train ahead
# 45                                              NaN
# 47                      due to congestion caused by
# 48               due to congestion caused by the sp

# %%
nj_transit_tweets_no_normal['train_line'] = train_line
# Out:
# /Users/castudi1/miniconda2/envs/lovepandas/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
nj_transit_tweets_no_normal.head(5)
# Out:
#                     id           created_at  \
# 42  869707161642782721  2017-05-30 20:08:40
# 44  869610601156423680  2017-05-30 13:44:58
# 45  869555488987516930  2017-05-30 10:05:58
# 47  869535347184721921  2017-05-30 08:45:56
# 48  869524519790280704  2017-05-30 08:02:55
#
#                                                  text  \
# 42  Train service in/out of Penn Station New York ...
# 44  RVL train #5176, the 1:28pm from Cranford is  ...
# 45  Train service in/out of Penn Station New York ...
# 47  (1 of 2) Trains in/out of PSNY is subject to u...
# 48  Train service in/out of PSNY is subject to up ...
#
#                                             tweetlink     created_at_date  \
# 42  https://twitter.com/NJTRANSIT_RVL/status/86970... 2017-05-30 20:08:40
# 44  https://twitter.com/NJTRANSIT_RVL/status/86961... 2017-05-30 13:44:58
# 45  https://twitter.com/NJTRANSIT_RVL/status/86955... 2017-05-30 10:05:58
# 47  https://twitter.com/NJTRANSIT_RVL/status/86953... 2017-05-30 08:45:56
# 48  https://twitter.com/NJTRANSIT_RVL/status/86952... 2017-05-30 08:02:55
#
#                                              reason train_line
# 42                                              NaN        RVL
# 44  due to track maintenance and a late train ahead        RVL
# 45                                              NaN        RVL
# 47                      due to congestion caused by        RVL
# 48               due to congestion caused by the sp        RVL

# %%
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('earlier congestion|congestion|delayed train|late connection|delayed connection|late trains|making additional stops|late train|heavy travel|accommodating customers'), 'blame'] = 'NJT late train'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('mechanical problem|mechanical problems'), 'blame'] = 'NJT mechanical problem'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('operational issue|operational issues|bridge opening|power shortage'), 'blame'] = 'NJT operational issues'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('police|fire|trespasser|motor vehicle accident|motor vehicle|Police'), 'blame'] = 'Police/Fire activity'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('medical|sick'), 'blame'] = 'Medical emergency'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('weather|downed tree|debris'), 'blame'] = 'Weather-related'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('signal'), 'blame'] = 'NJT signal problem'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('switch'), 'blame'] = 'NJT switch problem'
nj_transit_tweets_no_normal.loc[nj_transit_tweets_no_normal['text'].str.contains('congestion caused by the speed|speed|congestion caused by the spe|congestion caused by speed|congestion caused by sp'), 'blame'] = 'Amtrak speed limit'
# Out:
# /Users/castudi1/miniconda2/envs/lovepandas/lib/python2.7/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users
#
#                                                   text  \
# 42   Train service in/out of Penn Station New York ...
# 44   RVL train #5176, the 1:28pm from Cranford is  ...
# 45   Train service in/out of Penn Station New York ...
# 47   (1 of 2) Trains in/out of PSNY is subject to u...
# 48   Train service in/out of PSNY is subject to up ...
# 50   RVL train #5527, the 3:47pm from Union is up t...
# 51   RVL train #5179, the 4:02pm from North Branch ...
# 52   RVL train #5175, the 1:51pm from Bound Brook, ...
# 53   RVL train #5123, the 12:29pm from Westfield is...
# 54   RVL train #5176 the 1:24pm from Garwood Statio...
# 55   RVL train #5123, the 12:25pm from Cranford is ...
# 56   RVL train #5132, the 11:59am from Secaucus is ...
# 57   RVL train #5170, the 10:57am from Secaucus is ...
# 58   Train service in/out of Penn Station New York ...
# 59   Train service in/out of PSNY is subject to up ...
# 60   Train service in/out of PSNY is subject to up ...
# 61   RVL train #5176, the 1:28pm from Cranford is u...
# 62   RVL train #5132 the 11:28am from Cranford is u...
# 63   RVL train #5121 the 11:27am from Westfield is ...
# 66   Train Service in/out of PSNY is subject up to ...
# 67   RVL train #5175, the 1:29pm from Westfield, is...
# 72   (1 of 2) Train Service in/out of PSNY is subje...
# 73   (2 of 2) As a result, more of NJT trains to/fr...
# 75   Train service in/out of PSNY is now operating ...
# 79   Train service in/out of Penn Station New York ...
# 80   Train service in/out of PSNY is subject to up ...
# 83   Train service in/out of Penn Station New York ...
# 84   Train service in/out of Penn Station New York ...
# 85   Train service in/out of PSNY is subject to up ...
# 87   RVL train #5733 the 5:45pm from Raritan is CAN...
# ..                                                 ...
# 488  RVL train #5415, the 9:49am from Bound Brook i...
# 489  RVL train #5175, the 1:51pm from Bound Brook i...
# 490  RVL train #5123, the 12:51pm from Bound Brook ...
# 491  RVL train #5121 the 11:52am from Bridgewater i...
# 492  RVL train #5719, the 10:51am from Bound Brook ...
# 493  RVL train #5415, the 9:57am from Somerville is...
# 494  RVL train #5132 the 10:50am from Somerville is...
# 496  RVL train #5522 the 2:16pm from Raritan is up ...
# 497  RVL train #5445, the 6:42pm from Union, is up ...
# 500  RVL train #5517 the 11:07am from Netherwood is...
# 507  RVL train #5413, the 8:17am from Cranford is u...
# 510  RVL train #5123, the 12:34pm from Westfield, i...
# 512  RVL train #5127, the 2:51pm from Bound Brook, ...
# 513  RVL train #5175, the 1:51pm from Bound Brook, ...
# 515  RVL train #5123, the 12:59am from Somerville, ...
# 516  RVL train #5121, the 11:57am from Somerville, ...
# 517  RVL train #5719, the 10:51am from Bound Brook ...
# 518  RVL train #5175 the 1:54pm from Bridgewater is...
# 519  RVL train #5123,the 12:51pm from Bound Brook, ...
# 520  RVL train #5121, the 11:52am from Bridgewater ...
# 521  RVL train #5719 the 11:00am from Somerville is...
# 522  RVL train #5150, the 6:42pm from Somerville, i...
# 524  RVL train #5737, the 5:51pm from Westfield, is...
# 525  RVL train #5435, the 5:17pm from NPS, is CANCE...
# 526  RVL train #5175 the 1:51pm from Bound Brook is...
# 527  RVL train #5123, the 12:59pm from Somerville, ...
# 59                  due to congestion caused by the sp        RVL
# 60                due to congestion caused by the spee        RVL
# 61                            due to track maintenance        RVL
# 62                            due to track maintenance        RVL
# 63                            due to track maintenance        RVL
# 66              due to congestion caused by the speed         RVL
# 67                 due to programmed track maintenance        RVL
# 72                                   due to congestion        RVL
# 73                                                 NaN        RVL
# 75                                                 NaN        RVL
# 79                                                 NaN        RVL
# 80                  due to congestion caused by the sp        RVL
# 83                                                 NaN        RVL
# 84                                                 NaN        RVL
# 85                  due to congestion caused by the sp        RVL
# 87                         due to a mechanical problem        RVL
# ..                                                 ...        ...
# 488                           due to track maintenance        RVL
# 489                           due to track maintenance        RVL
# 490                           due to track maintenance        RVL
# 491                           due to track maintenance        RVL
# 492                           due to track maintenance        RVL
# 493                           due to track maintenance        RVL
# 494               due to an earlier mechanical problem        RVL
# 496                          due to mechanical problem        RVL
# 497  due to congestion caused by an earlier switch ...        RVL
# 500                      due to weather-related issues        RVL
# 507                            due to a switch problem        RVL
# 510                due to an earlier operational issue        RVL
# 512                due to programmed track maintenance        RVL
# 513                due to programmed track maintenance        RVL
# 515                due to programmed track maintenance        RVL
# 516                due to programmed track maintenance        RVL
# 517                           due to track maintenance        RVL
# 518                      due to programmed maintenance        RVL
# 519                due to programmed track maintenance        RVL
# 520                           due to track maintenance        RVL
# 521           due to congestion from track maintenance        RVL
# 522  due to an operational issue, resulting from an...        RVL
# 524  due to making additional stops for an earlier ...        RVL
# 525                        due to an operational issue        RVL
# 526                      due to programmed maintenance        RVL
# 527                due to programmed track maintenance        RVL
# 528                           due to track maintenance        RVL
# 529                           due to track maintenance        RVL
# 530                           due to track maintenance        RVL
# 531                    due to an earlier delayed train        RVL
#
#                       blame
# 42                      NaN
# 44           NJT late train
# 45                      NaN
# 47           NJT late train
# 48           NJT late train
# 50           NJT late train
# 51       NJT signal problem
# 52           NJT late train
# 53                      NaN
# 54                      NaN
# 55                      NaN
# 56           NJT late train
# 57   NJT operational issues
# 58                      NaN
# 59           NJT late train
# 60       Amtrak speed limit
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 66       Amtrak speed limit
# 67                      NaN
# 72           NJT late train
# 73                      NaN
# 75                      NaN
# 79                      NaN
# 80           NJT late train
# 83                      NaN
# 84                      NaN
# 85           NJT late train
# 87   NJT mechanical problem
# ..                      ...
# 488                     NaN
# 489                     NaN
# 490                     NaN
# 491                     NaN
# 492                     NaN
# 493                     NaN
# 494  NJT mechanical problem
# 496  NJT mechanical problem
# 497      NJT switch problem
# 500         Weather-related
# 507      NJT switch problem
# 510  NJT operational issues
# 512                     NaN
# 513                     NaN
# 515                     NaN
# 516                     NaN
# 517                     NaN
# 518                     NaN
# 519                     NaN
# 520                     NaN
# 521          NJT late train
# 522  NJT operational issues
# 524          NJT late train
# 525  NJT operational issues
# 526                     NaN
# 527                     NaN
# 528                     NaN
# 529                     NaN
# 530                     NaN
# 531          NJT late train
#
# [249 rows x 8 columns]

# %%
nj_transit_tweets_no_normal.to_csv(string, index=False)
